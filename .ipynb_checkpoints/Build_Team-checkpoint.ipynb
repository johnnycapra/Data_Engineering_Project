# %%
import pandas as pd
import tkinter as tk
from tkinter import ttk

# %%
#create list of players and stats

# Read the DataFrames
rushing_df = pd.read_csv('output_data/rushing_cleaned.csv')
injury_df = pd.read_csv('output_data/injury_cleaned.csv')

# Perform left join on the "Player" column
player_data = pd.merge(rushing_df, injury_df, on='player', how='left')

# Display the merged DataFrame
player_data.head()
# Out:
#           player pos     yds    td position report_primary_injury  \
# 0    Josh Jacobs  RB  1653.0  12.0       RB             Quadricep
# 1    Josh Jacobs  RB  1653.0  12.0       RB             Quadricep
# 2    Josh Jacobs  RB  1653.0  12.0       RB                   Hip
# 3  Derrick Henry  RB  1538.0  13.0      NaN                   NaN
# 4     Nick Chubb  RB  1525.0  12.0      NaN                   NaN
#
#                 report_secondary_injury report_status practice_primary_injury  \
# 0                                  Calf  Questionable               Quadricep
# 1                                  Hand  Questionable               Quadricep
# 2  Not injury related - personal matter  Questionable                     Hip
# 3                                   NaN           NaN                     NaN
# 4                                   NaN           NaN                     NaN
#
#         practice_secondary_injury
# 0                            Calf
# ...

# %%
# Get Fantasy Football Team Names

# Initializing DF for team picks
team_df = pd.DataFrame(columns=[
    'Team Name',
    'QB',
    'RB',
    'WR',
    'TE',
])

team_df
# Out:
# Empty DataFrame
# Columns: [Team Name, QB, RB, WR, TE]
# Index: []

# %%
#establishing QB, RB, WR, TE lists

qb_names = rushing_df[rushing_df['pos'] == 'QB']['player']
rb_names = rushing_df[rushing_df['pos'] == 'RB']['player']
wr_names = rushing_df[rushing_df['pos'] == 'WR']['player']
te_names = rushing_df[rushing_df['pos'] == 'TE']['player']

# %%
import pandas as pd
import tkinter as tk
from tkinter import ttk

#create list of players and stats

# Read the DataFrames
rushing_df = pd.read_csv('output_data/rushing_cleaned.csv')
injury_df = pd.read_csv('output_data/injury_cleaned.csv')

# Perform left join on the "Player" column
player_data = pd.merge(rushing_df, injury_df, on='player', how='left')

# Display the merged DataFrame
player_data




# Get Fantasy Football Team Names

# Initializing DF for team picks
team_df = pd.DataFrame(columns=[
    'Team Name',
    'QB',
    'RB',
    'WR',
    'TE',
])

team_df




#establishing QB, RB, WR, TE lists

qb_names = rushing_df[rushing_df['pos'] == 'QB']['player']
rb_names = rushing_df[rushing_df['pos'] == 'RB']['player']
wr_names = rushing_df[rushing_df['pos'] == 'WR']['player']
te_names = rushing_df[rushing_df['pos'] == 'TE']['player']


class DataFrameViewer(tk.Tk):
    def __init__(self, dataframe, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
        self.title("DataFrame Viewer")

        # Add a textbox
        self.textbox = tk.Entry(self)
        self.textbox.pack(side="top", pady=5)

        # Add a button
        self.add_team_button = tk.Button(self, text="Add Team Name", command=self.add_team_name)
        self.add_team_button.pack(side="top", pady=5)

        # Create a Treeview widget
        self.tree = ttk.Treeview(self, columns=list(dataframe.columns), show="headings")

        # Add columns to the Treeview
        for col in dataframe.columns:
            self.tree.heading(col, text=col)

        # Insert data into the Treeview
        for i, row in dataframe.iterrows():
            self.tree.insert("", "end", values=list(row))

        # Add a vertical scrollbar
        scrollbar = ttk.Scrollbar(self, orient="vertical", command=self.tree.yview)
        self.tree.configure(yscrollcommand=scrollbar.set)

        # Pack the Treeview and scrollbar
        self.tree.pack(side="left", fill="both", expand=True)
        scrollbar.pack(side="right", fill="y")

        # Add a dropdown for team selection
        self.teams = []  # You need to populate this list with the team names
        self.team_dropdown = ttk.Combobox(self, values=self.teams)
        self.team_dropdown.pack(side="top", pady=5)

        # Add a dropdown for position selection
        positions = ['QB', 'RB', 'WR', 'TE']
        self.position_dropdown = ttk.Combobox(self, values=positions, state="readonly")
        self.position_dropdown.pack(side="top", pady=5)
        self.position_dropdown.bind("<<ComboboxSelected>>", self.update_player_dropdown)

        # Add a dropdown for player data
        players = []  # You need to populate this list based on the selected position
        self.player_dropdown = ttk.Combobox(self, values=players)
        self.player_dropdown.pack(side="top", pady=5)
        self.player_dropdown.bind("<<ComboboxSelected>>", self.update_and_display_stats)

        # Add labels for displaying stats
        self.yards_label = tk.Label(self, text="Yards:")
        self.yards_label.pack(side="top", pady=5)

        self.injury1_label = tk.Label(self, text="Injury 1:")
        self.injury1_label.pack(side="top", pady=5)

        self.injury2_label = tk.Label(self, text="Injury 2:")
        self.injury2_label.pack(side="top", pady=5)
        
        # Add a button for adding selected player to the team
        self.add_player_button = tk.Button(self, text="Add Player to Team", command=self.add_player_to_team)
        self.add_player_button.pack(side="top", pady=5)

        # Initialize a dictionary to store selected players for each team
        self.selected_players_dict = {}
        
        # Add a button for exporting selected team values to CSV
        self.export_button = tk.Button(self, text="Export Team to CSV", command=self.export_team_to_csv)
        self.export_button.pack(side="top", pady=5)

    def add_team_name(self):
        # Get the text from the textbox
        team_name = self.textbox.get()

        # Add the team name to the Treeview
        self.tree.insert("", "end", values=[team_name])

        # Update the team dropdown with the new team name
        self.teams.append(team_name)
        self.team_dropdown["values"] = self.teams

    def update_player_dropdown(self, event):
        # Update the player dropdown based on the selected position
        selected_position = self.position_dropdown.get()
        if selected_position == 'QB':
            players = qb_names.tolist()
        elif selected_position == 'RB':
            players = rb_names.tolist()
        elif selected_position == 'WR':
            players = wr_names.tolist()
        elif selected_position == 'TE':
            players = te_names.tolist()
        else:
            players = []

        self.player_dropdown["values"] = players

    def display_player_stats(self, player):
        # Display stats for the selected player
        selected_player_data = player_data[player_data['player'] == player]
        yards_value = selected_player_data['yds'].values[0] if not selected_player_data.empty else ""
        injury1_value = selected_player_data['report_primary_injury'].values[0] if not selected_player_data.empty else ""
        injury2_value = selected_player_data['report_secondary_injury'].values[0] if not selected_player_data.empty else ""

        self.yards_label["text"] = f"Yards: {yards_value}"
        self.injury1_label["text"] = f"Injury 1: {injury1_value}"
        self.injury2_label["text"] = f"Injury 2: {injury2_value}"
        
    def update_and_display_stats(self, event):
        selected_player = self.player_dropdown.get()
        if selected_player:
            self.display_player_stats(selected_player)

    def add_player_to_team(self):
        # Get the selected team name from the dropdown
        selected_team = self.team_dropdown.get()

        # Check if a team is selected
        if selected_team:
            # Get the selected player from the player dropdown
            selected_player = self.player_dropdown.get()

            # Check if a player is selected
            if selected_player:
                # Add the selected player to the team's list of selected players
                if selected_team not in self.selected_players_dict:
                    self.selected_players_dict[selected_team] = pd.DataFrame(columns=rushing_df.columns)

                # Inside the add_player_to_team method
            if selected_player not in self.selected_players_dict[selected_team]['player'].tolist():
                selected_player_data = rushing_df[rushing_df['player'] == selected_player]

                # Exclude empty or all-NA columns before concatenation
                non_empty_columns = selected_player_data.columns[selected_player_data.notna().any()].tolist()
                selected_player_data = selected_player_data[non_empty_columns]

                self.selected_players_dict[selected_team] = pd.concat([self.selected_players_dict[selected_team], selected_player_data],
                                                                      ignore_index=True)
                print(f"Player '{selected_player}' added to Team '{selected_team}'")


                # Clear the player dropdown
                self.player_dropdown.set("")

                # Check if 4 players are selected for the team
                if len(self.selected_players_dict[selected_team]) == 4:
                    print(f"Team '{selected_team}' is complete with 4 players.")
                    self.export_team_to_csv(selected_team)

                else:
                    print(f"Player '{selected_player}' is already selected for Team '{selected_team}'")
            else:
                print("Please select a player.")

        else:
            print("Please select a team.")
            
    def export_team_to_csv(self, selected_team):
            # Filter the dataframe for the selected team and players
            selected_team_data = team_df[team_df['Team Name'] == selected_team]
            selected_players = self.selected_players_dict[selected_team]
            selected_team_data = selected_team_data[selected_team_data['QB'].isin(selected_players) |
                                                    selected_team_data['RB'].isin(selected_players) |
                                                    selected_team_data['WR'].isin(selected_players) |
                                                    selected_team_data['TE'].isin(selected_players)]

            # Choose a filename for the CSV export (you can modify this as needed)
            filename = f"{selected_team}_team_export.csv"

            # Export the selected team data to CSV
            selected_team_data.to_csv(filename, index=False)
            print(f"Team '{selected_team}' exported to {filename}")
        
if __name__ == "__main__":
    app = DataFrameViewer(team_df)
    app.mainloop()
